# %%
# !git config --global --list

# %%
# !git config --global user.name 'Tony'
# !git config --global user.email 'getonyiyy@gmail.com'

# %%
# !git config --global --list

# %%
# Generate the token from github
"""
- Navigate to 'https://github.com/getony/'
- First click on  the icon symbol in the right top corner and
- then under it click 'Settings'
- At the bottom of the left side, click '<> Developer settings'
- On the left side, click on 'Personal access tokens', and
  select 'Tokens (classic)'
- Click on 'Generate new token'
  ->'Generate new token(classic)-For general use'
- Enter a Note:"colab-access" and select on 'repo', click on
  'Generate token' button
- Save the token in variable below
"""
token = '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'
username='getony'
repo='datasc_study'

# %%
"""
In the folder symbol on the left side, select the
Mount Drive. A drive folder is created in the /content
folder
"""

# %%
# %cd /content/drive/MyDrive/"Colab Notebooks"

# %%
# !git clone https://{token}@github.com/{username}/{repo}

# %%
# !ls

# %%
# %cd {repo}

# %%
# !ls

# %%
"""
In the colab notebook(where we are running), click on
File->'Save a copy in 'GitHub'

Enter the following
Repository: getony/datasc_study
File path: datasc_study/github_setup.ipynb
Commit message: Created the github_setup file

Keep 'Include a link to Colaboratory' selected
"""

# %%
# !git pull

# %%
# !ls -l

# %%
# !mkdir pca

# %%
# %cd pca

# %%
# !ls -l

# %%
#!touch test.txt

# %%
"""
Mount the google drive by clicking on the middle button(in the left pane at
the top). A /drive folder is added to /content folder
Clicking on File->New Notebook, will create a new notebook.
When the new notebook opens, rename the file (in the top of the notebook), to
the required name(say, basic01.ipynb). Next select File->Move and move this to
appropriate directory in the repository.

You can only open this file by using File->Open Notebook->select the file.
You **CANNOT** open this file by double-clicking on this.
"""

# %%
# %cd ..

# %%
# !git status

# %%
# !git add basics/

# %%
# !git status

# %%
# Make necessary changes to the file, save it.
# when ready do git add .
#!git add .

# %%
# !git status

# %%
# !git commit -m "Created a linear-regression sample code "

# %%
# !git log --oneline

# %%
# !pwd

# %%
# !git push origin

# %%
# !git status

# %%
# !ls -l

# %%
# !touch test.txt

# %%
# !git status

# %%
# !git add .

# %%
# !git status

# %%
# !git commit -m 'Added a new file'

# %%
# !git log --oneline

# %%
# !git push origin

# %%
# !git status

# %%
# !git add .

# %%
# !git commit --amend -m 'Updated basic01.ipynb with linear-regression'

# %%
# !git log --oneline

# %%
# !git push origin

# %%
# !pwd

# %%
# !touch notes.txt

# %%
# !git status

# %%
# !git add .

# %%
# !git status

# %%
# !git commit -m 'Added a notes file for notebook information'

# %%
# !git log --oneline

# %%
# !git pull . https://{token}@github.com/{username}/{repo}

# %%
# !git stash

# %%
# !git push origin  https://{token}@github.com/{username}/{repo}

# %%
# %cd data_science

# %%
# In some cases the github deletes the Personal Access Token !!!
# So we have to generate a new token. Also we have to update the
# local repository with the new token. The next cell shows the
# repo still holding a stale access token.

# %%
# !git remote -v

# %%
token='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'

# %%
# Update the newly generated token to the repository
# !git remote set-url origin https://{token}@github.com/{username}/{repo}

# %%
# !git push origin master

# %%
# !git pull

# %%
# !git config pull.rebase true

# %%
# !git pull

# %%
# !git push origin

# %%
# !pwd

# %%
# %cd /content/drive/MyDrive/"Colab Notebooks"/datasc_study/

# %%
# !pwd

# %%
# !git status

# %%
# !git add basics/model_validation.ipynb

# %%
# !git status

# %%
# !git commit -m 'code added to demonstrate model validation techniques'

# %%
# !git log --oneline

# %%
# !git push origin

# %%
# !git pull origin

# %%
# !git push origin

# %%
# !pwd

# %%
# !git status

# %%
# !git add .

# %%
# !git status

# %%
# !git add basics/best_model.ipynb

# %%
# !git status

# %%
# !git commit -m 'added code to work with hyperparameters, validation curve, learning curve'

# %%
# !git log --oneline

# %%
# !git push origin

# %%
# !pwd

# %%
# %cd /content/drive/MyDrive/"Colab Notebooks"/datasc_study/

# %%
# !git status

# %%
# !git add .

# %%
# !git status

# %%
# !git commit -m 'added code on various feature engineering methods'

# %%
# !git log --oneline

# %%
# !git push origin

# %%
# !pwd

# %%
# %cd /content/drive/MyDrive/"Colab Notebooks"/datasc_study/

# %%
# !mkdir naive_bayes

# %%
# !pwd

# %%
# !git status

# %%
# !git add naive_bayes/gaussian_naive_bayes.ipynb

# %%
# !git status

# %%
# !git commit -m 'added code for gaussian naive bayes'

# %%
# !git log --oneline

# %%
# !git push origin

# %%
# !git status

# %%
# !git add .

# %%
# !git status

# %%
# !git commit -m 'added a multinomial naive bayes example'

# %%
# !git log --oneline

# %%
# !git push origin

# %%
# !pwd

# %%
# %cd /content/drive/MyDrive/"Colab Notebooks"/datasc_study/

# %%
# !mkdir linear_regression

# %%
# !pwd

# %%
# !git status

# %%
# !git diff naive_bayes/multinomial_naive_bayes.ipynb

# %%
# !git restore naive_bayes/multinomial_naive_bayes.ipynb

# %%
# !git status

# %%
# !git add .

# %%
# !git status

# %%
# !git commit -m 'added code for LinearRegression, GaussianFeatures, Ridge and Lasso'

# %%
# !git log --oneline

# %%
# !git push origin

# %%
# !git status

# %%
# !git commit -m 'Added code for LinearRegression, GaussianFeatures, Ridge and Lasso'

# %%
# !git log --oneline

# %%
# !git push origin

# %%
# !pwd

# %%
# %cd /content/drive/MyDrive/"Colab Notebooks"/datasc_study

# %%
# !mkdir support_vector_machines

# %%
# !pwd

# %%
# !git status

# %%
# !git add .

# %%
# !git status

# %%
# !git commit -m 'added basic sample for support vector machines'

# %%
# !git push origin

# %%
# !pwd

# %%
# %cd /content/drive/MyDrive/"Colab Notebooks"/datasc_study

# %%
# !git status

# %%
# !mkdir tree_classifiers

# %%
# !git status

# %%
# !git status

# %%
# !git add support_vector_machines/svm_faces.ipynb

# %%
# !git status

# %%
# !git commit -m 'added code for application of svc to faces'

# %%
# !git log --oneline

# %%
# !git push origin

# %%
# !git status

# %%
# !git add tree_classifiers/

# %%
# !git status

# %%
# !git status

# %%
# !git add tree_classifiers/tree_basics.ipynb

# %%
# !git status

# %%
# !rm tree_classifiers/Untitled1.ipynb

# %%
# !git status

# %%
# !git restore --staged tree_classifiers/Untitled1.ipynb

# %%
# !git status

# %%
# !git commit -m 'added code for tree based classifier and regressor'

# %%
# !git log --oneline

# %%
# !git push origin

# %%
# !git status

# %%
# !git add .

# %%
# !git status

# %%
# !git commit -m 'added code for application of random forest classifier to digits'

# %%
# !git log --oneline

# %%
# !git push origin

# %%
# !git status

# %%
# !git add .

# %%
# !git commit --amend -m "added code for application of random forest classifier to digits"

# %%
# !git push origin --force

# %%
# %pwd

# %%
# %cd datasc_study

# %%
# !git status

# %%
# !git status

# %%
# !git add pca/

# %%
# !git status

# %%
# !git add pca/pca_basics.ipynb

# %%
# !git status

# %%
# !git restore --staged pca/Untitled1.ipynb

# %%
# !git status

# %%
# !rm pca/Untitled1.ipynb

# %%
# !git status

# %%
# !git commit -m 'added sample for Principal Component Analysis basics'

# %%
# !git log --oneline

# %%
# !git remote

# %%
# !git remote -vv

# %%
# !git push origin

# %%
# !git status

# %%
# !git status

# %%
# !git status

# %%
# %pwd

# %%
# %cd datasc_study

# %%
# !git status

# %%
# !git add pca/pca_sample_digits.ipynb

# %%
# !git status

# %%
# !git commit -m 'Added sample code to use PCA with digits'

# %%
# !git log --oneline

# %%
# !git push origin

# %%
# !git status

# %%
# !git add pca/pca_sample_faces.ipynb

# %%
# !git commit -m 'Added sample based on PCA applied to faces'

# %%
# !git log --oneline

# %%
# !git push origin

# %%
# %pwd

# %%
# %cd datasc_study

# %%
# !dir

# %%
# !mkdir manifolds

# %%
# %cd manifolds

# %%
# !ls ../tree_classifiers

# %%
# !git status

# %%
# !ls

# %%
# !ls manifolds/

# %%
# !ls manifolds/

# %%
# !git status

# %%
# !git add manifolds/manifold_basics.ipynb

# %%
# !git status

# %%
# !git restore --staged manifolds/github-setup.ipynb

# %%
# !git status

# %%
# !git commit -m 'Added codes for manifold basics such as MDS and LocallyLinearEmbedding '

# %%
# !git log --oneline

# %%
# !git push origin

# %%
# %pwd

# %%
# %cd datasc_study

# %%
# !git status

# %%
# !git add manifolds/manifold_sample_china.ipynb

# %%
# !git status

# %%
# !git log --oneline

# %%
# !git commit -m 'Addes code for manifold sample based on china image'

# %%
# !git log --oneline

# %%
# !git remote -vv

# %%
# !git push origin

# %%
# %pwd

# %%
# !git status

# %%
# !ls

# %%
# %cd manifolds

# %%
# !ls

# %%
# !git status

# %%
# !git push origin
